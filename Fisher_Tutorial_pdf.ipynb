# %% [markdown]
# # Example notebook: Fisher forecast

# %% [markdown]
# Authors: Sambit Giri, Adélie Gorce, Ian Hothi
#
# Date: June 2025
#
# In this notebook, we show how to obtain Fisher results from statistics pre-computed on the simulation dataset with the `compute_statistic` script.

# %%
import numpy as np
import h5py
import tqdm
import matplotlib.pyplot as plt
from matplotlib import colors
import corner

import os
import numpy as np

# %% [markdown]
# # About the data

# %% [markdown]
# The data has been simulated using 21cmFast. The XY plane has an extent of 250Mpc, with 256 pixels on each side. The line-of-sight (redshift) has been simulated to be between z = 8.82 (144.60 MHz) and z = 9.33 (137.46 MHz), comprising 128 frequency channels. The three parameters chosen to be changed are the virial temperature, maximum bubble size, and the ionising efficiency parameter—these were all found to have the strongest impact on the signal.
#
# These are the parameter variations (fiducial value $\pm$ change):
#
# - $T_{Vir}$: $50000\pm 5000$
# - $R_{Max}$: $15\pm 5 Mpc$
# - $\zeta$: $30\pm 5$,
# 400 simulations were run for each parameter value, which will be used for the derivatives. In the loaded files, there will be two files for each parameter, one corresponding to the plus value - for example, for $T_{Vir}$ tue value would be 50000 + 5000. Whereas the minus value would be 50000 - 5000.
#
#
# 400 simulations were run with the fiducial values, this will serve to calculate the covariances of the statistics.

# %%
# Folder where the data is stored
ddir = '/data/cluster/agorce/SKA_chapter_simulations/'
# ddir = './SKA_chapter_simulations/' # This folder can be created inside the repository folder. It will be ignored during the git commit.
# File with fiducial lightcone
file = ddir+'Lightcone_FID_400_Samples.h5'

# %%
statname = 'pdf'

# %% [markdown]
# ## Global parameters

# %%
# cosmology
h = 0.6774

# %%
# Astro params
params = ['ION_Tvir_MIN','R_BUBBLE_MAX','HII_EFF_FACTOR']
Fisher_Param = ['$T_{Vir}$','$R_{Max}$','$\zeta$']
nparams = len(params)
# parameter values for fiducial simulation
fid = [pow(10,4.7),15,30]
# parameter range for derivatives
delta_params = [pow(10,4.740362689494244)-pow(10,4.653212513775344), 10, 10]

# Pdf params
dr = 1.
bin_edges = np.arange(-100, 100, step=dr)
bin_centres = 0.5 * (bin_edges[1:] + bin_edges[:-1])
nbins = bin_centres.size

# %%
# simulation files
files = [ddir+'Lightcone_FID_400_Samples.h5']
[files.extend(
    [f'{ddir}Lightcone_{p}_400_Samples_Plus.h5', f'{ddir}Lightcone_{p}_400_Samples_Minus.h5']) for p in params]
print(files)
# Out:
# ['/data/cluster/agorce/SKA_chapter_simulations/Lightcone_FID_400_Samples.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_ION_Tvir_MIN_400_Samples_Plus.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_ION_Tvir_MIN_400_Samples_Minus.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_R_BUBBLE_MAX_400_Samples_Plus.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_R_BUBBLE_MAX_400_Samples_Minus.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_HII_EFF_FACTOR_400_Samples_Plus.h5', '/data/cluster/agorce/SKA_chapter_simulations/Lightcone_HII_EFF_FACTOR_400_Samples_Minus.h5']

# %% [markdown]
# Parameters describing the simulations:

# %%
# Read h5py file for metadata
with h5py.File(files[0], 'r') as f:
    frequencies = f['frequencies'][...]
    redshifts = f['redshifts'][...]
    box_length = float(f['box_length'][0])/h  # Mpc
    box_dim = int(f['ngrid'][0])
    n_samp = int(f['nrealisations'][0])
nfreq = frequencies.size
print(f'Lightcone runs from z={redshifts.min():.2f} to z = {redshifts.max():.2f}.')
# Out:
# Lightcone runs from z=8.82 to z = 9.33.

# %% [markdown]
# # Loading Data and Statistics estimation

# %%
obs_time = 100.  # hours
layout = 'AAstar'

# %%
# container dict: keys will be e.g. 'PS_param_1_plus', 'PS_fid', etc.
stat_data = {}
keys = []
count = 0
for fpath in tqdm.tqdm(files):

    key = os.path.basename(fpath)[:-3].replace('Lightcone_', '').replace('_400_Samples', '')
    keys.append(key)
    with h5py.File(fpath, 'r') as f:
        stat_data[key] = {
            'stat_clean':  f['pdf_clean'][...],  # ps of clean cosmological signal
            'bin_centres': f['pdf_bins'][...],  # centres of the bins
        }
        if 'FID' in key:
            stat_data[key].update({
                'stat_noise':  f[f'pdf_noise_{layout}_{int(obs_time)}hrs'][...],  # ps of noise
                'stat_obs':  f[f'pdf_obs_{layout}_{int(obs_time)}hrs'][...],  # ps of smoothed (noise + cosmological signal)
            })

# now you can refer to, e.g. PS_data['PS_R_BUBBLE_MAX_plus']['PS'] 
# and PS_data['PS_R_BUBBLE_MAX_plus']['ks'] etc.
print(f'Found {len(stat_data)} {statname} datasets.')
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [00:00<00:00, 63.09it/s]
# Found 7 pdf datasets.

# %%
# factor = 6

# inds = np.arange(3, bin_centres.size, step=factor)
# new_hist = [np.mean(np.take(stat_data[keys[0]]['stat_clean'][12], np.arange(i, i+1), mode='clip')) for i in np.arange(3, bin_centres.size, step=factor)]
# new_bins = [np.mean(np.take(bin_centres, np.arange(i, i+1), mode='clip')) for i in np.arange(3, bin_centres.size, step=factor)]

# plt.plot(stat_data['FID']['bin_centres'], stat_data[keys[0]]['stat_clean'][12])
# test, bin_test = np.histogram(stat_data[keys[0]]['stat_clean'][12], bins=bin_edges[::2], density=True)
# plt.plot(new_bins, new_hist, '.', label='test')
# print(new_bins)
# plt.xlim(-30, 20)

# %%
# re-binning
factor = 6

# bin_centres = (bin_centres[1::factor] + bin_centres[:-1:factor]) / factor
inds = np.arange(3, bin_centres.size, step=factor)
bin_centres = np.array([np.mean(np.take(bin_centres, np.arange(i, i+1), mode='clip')) for i in inds])
nbins = bin_centres.size
for key in keys:
    with h5py.File(fpath, 'r') as f:
        stat_data[key].update({
            'stat_clean': np.array([np.mean(np.take(stat_data[key]['stat_clean'], np.arange(i, i+1), mode='clip', axis=1), axis=1) for i in inds]).T,
            # (stat_data[key]['stat_clean'][:, 1::factor]+stat_data[key]['stat_clean'][:, :-1:factor])/factor,
        })
        if 'FID' in key:
            stat_data[key].update({
                'bin_centres': bin_centres,
                'stat_noise': np.array([np.mean(np.take(stat_data[key]['stat_noise'], np.arange(i, i+1), mode='clip', axis=1), axis=1) for i in inds]).T,
                # (stat_data[key]['stat_noise'][:, 1::factor]+stat_data[key]['stat_noise'][:, :-1:factor])/factor,
                'stat_obs': np.array([np.mean(np.take(stat_data[key]['stat_obs'], np.arange(i, i+1), mode='clip', axis=1), axis=1) for i in inds]).T,
                #(stat_data[key]['stat_obs'][:, 1::factor]+stat_data[key]['stat_obs'][:, :-1:factor])/factor,
            })

# %%
stat_data['FID']['stat_obs'].shape

plt.figure()
for i, key in enumerate(['stat_clean', 'stat_noise', 'stat_obs']):
    plt.plot(stat_data['FID']['bin_centres'], np.mean(stat_data['FID'][key], axis=0), label=key, color=f'C{i}', ds='steps-mid')
    plt.errorbar(
        stat_data['FID']['bin_centres'],
        np.mean(stat_data['FID'][key], axis=0),
        yerr=np.std(stat_data['FID'][key], axis=0),
        color=f'C{i}', capsize=3, lw=0., elinewidth=1.)
# plt.xlim(-1, 50)
plt.legend(frameon=False)
plt.ylim(bottom=0)
plt.title('FID')
plt.xlabel(f'$\delta T_b$ [mK]')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %% [markdown]
# ## Fisher Matrix

# %% [markdown]
# Under the assumption that the likelihood is a multivariate Gaussian (mean vectors are sufficient information for the covariance matrix), the Fisher matrix is defined as:
#
# $$F^\theta_{ij} = \frac{\partial \textbf{S}}{\partial\theta_i} \mathbf{\Sigma}^{-1} \frac{\partial \textbf{S}}{\partial\theta_j},$$
#
# where  $\frac{\partial \textbf{S}}{\partial\theta_i}$ is the change in statistic S under a change in paramrter i of $\partial\theta_j$. Here, $\mathbf{\Sigma}$ is the the covariance matrix, given my the fiducial simulation set.

# %% [markdown]
# ### Derivatives

# %% [markdown]
# Let us first calculate $\frac{\partial \textbf{S}}{\partial\theta_i}$ for out three astrophysical parameters:

# %%
# Compute the finite‐difference derivatives for each k‐bin & sample
# from the statistics derived from the clean signal
stat_derivs = np.zeros((len(params), n_samp, bin_centres.size))
for ip, param in enumerate(params):
    stat_derivs[ip] = (stat_data[f'{param}_Plus']['stat_clean'] - stat_data[f'{param}_Minus']['stat_clean']) / delta_params[ip]

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharex=True)
for ip, param in enumerate(Fisher_Param):
    axes[ip].plot(stat_data['FID']['bin_centres'], np.mean(stat_derivs[ip], axis=0), ds='steps-mid', color='C0')
    axes[ip].errorbar(
        stat_data['FID']['bin_centres'],
        np.mean(stat_derivs[ip], axis=0),
        yerr=np.std(stat_derivs[ip], axis=0),
        capsize=3, lw=0., elinewidth=1., color='C0')
    axes[ip].set_title(param)
    axes[ip].set_xlabel(f'$\delta T_b$ [mK]')
# plt.ylim(bottom=0)
axes[0].set_ylabel(r'd$f$/d$\theta$')
# axes[0].set_xlim(-10, 25)
# Out:
# Text(0, 0.5, 'd$f$/d$\\theta$')

# %% [markdown]
# ### Data covariance

# %% [markdown]
# The data covariance will have two contributions:
# 1. Statistical errors coming from the sample variance of your estimator (variance computed across the statistics estimated from a number of realisations of a clea simulation).
# 2. Noise errors coming from instrumental (SKA AA* layout) noise
#
# We obtain the data covariance from 400 realisations of the "observed" maps.

# %% [markdown]
# Let us whiten the data to get rid of any order of magnitude issues that may arise (note that this leads to the covariance having a diagonal of ones):

# %%
## Whitening step ##
stat_fid = stat_data['FID']['stat_obs'] 
std_fid = np.std(stat_fid, axis=0)

# remove modes above smoothing limit where there is no variance
mask = std_fid > 0.
white_fid = stat_fid[:, mask]/std_fid[mask]
# Whitening the derivatives
stat_derivs_white = stat_derivs[..., mask]/std_fid[mask]

# %%
covariance = np.cov(white_fid, rowvar=False)
# Check the condition of the covariance to ensure numerical inversion is stable:
print(f'log Condition number of the covariance matrix: {np.log10(np.linalg.cond(covariance)):.2f} (should be <= 7).')
# Out:
# log Condition number of the covariance matrix: 1.91 (should be <= 7).

# %%
plt.figure()
plt.pcolormesh(bin_centres[mask], bin_centres[mask], covariance, cmap='coolwarm', norm=colors.SymLogNorm(linthresh=.1, vmin=-1., vmax=1.))
plt.title('Data covariance')
plt.xlabel(f'$\delta T_b$ [mK]')
plt.ylabel(f'$\delta T_b$ [mK]')
plt.colorbar(label=r'$C$')

# %% [markdown]
# Let us check the stability of the inversion:

# %%
# Checking stability of the covariance by looking at the value of the off-diagonal terms of Sigma dot Sigma-1
I = np.log10(abs(np.matmul(np.linalg.inv(covariance), covariance))+1e-16)

plt.figure()
plt.pcolormesh(bin_centres[mask], bin_centres[mask], I)
plt.colorbar().set_label('log$_{10} C^{-1}C$')
plt.xlabel(f'$\delta T_b$ [mK]')
plt.ylabel(f'$\delta T_b$ [mK]')

plt.figure()
plt.hist(I[I!=1.].reshape(-1), bins=100)
plt.xlabel('log$_{10} C^{-1}C$')
# Out:
# Text(0.5, 0, 'log$_{10} C^{-1}C$')

# %% [markdown]
# We can now calculate the Fisher Matrix for different sub-samples to check convergence

# %%
# Number of realisations to look at when checking convergence
samples = np.arange(5, n_samp+5, 5)

# Initialising Fishers 
stat_Fisher = np.zeros((samples.size, nparams, nparams))
stat_Fisher_Inv = np.zeros((samples.size, nparams, nparams))

# %%
# Calculating the Fisher matrix for a given sample of derivatives 
for k, sample_size in enumerate(samples):
    deriv_sample = np.mean(stat_derivs_white[:, :sample_size, :], axis=1)
    for i in range(nparams):
        for j in range(nparams):  
            stat_Fisher[k, i, j] = np.dot(deriv_sample[i], np.dot(np.linalg.inv(covariance), deriv_sample[j]))
    stat_Fisher_Inv[k] = np.linalg.inv(stat_Fisher[k])

# %%
plt.figure(figsize=(12, 4))
for i, param in enumerate(params):
    plt.plot(samples, [np.diag(stat_Fisher_Inv[k])[i]-np.diag(stat_Fisher_Inv[-1])[i] for k in range(samples.size)], marker='.', label=param, alpha=.5)
plt.legend()
plt.ylabel(r'$\sigma^2_{ii}$')
plt.xlabel('Number of samples')
plt.title('Convergence of the Fisher inverse matrix diagonal elements')
# plt.ylim(-20, 20)
# Out:
# Text(0.5, 1.0, 'Convergence of the Fisher inverse matrix diagonal elements')

# %% [markdown]
# ### Plot and save posterior

# %% [markdown]
# Plot the resulting Gaussian distribution with appropriate covariance

# %%
fisher_data = np.random.multivariate_normal(fid, stat_Fisher_Inv[-1], size=100000)

# %%
_ = corner.corner(
    fisher_data,
    labels=Fisher_Param,
    plot_datapoints=False,  
    levels=(0.68,0.95),
    truths=fid)

# %% [markdown]
# If the above corner plot looks fine, then save the (3,3) covariance matrix.

# %%
np.savetxt(f'./output/posterior_covariance_matrix_{layout}_{int(obs_time)}hours_pdf.txt', stat_Fisher_Inv[-1])
